# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib

def plot_logs(evaluation_cost, evaluation_accuracy, training_cost, training_accuracy):
    f, (ax1, ax2) = plt.subplots(1, 2)
    f.set_figwidth(10)
    ax1.plot(evaluation_cost,label= 'test')
    ax1.plot(training_cost, label='train')
    ax1.set_title('Cost')
    ax1.legend()
    ax2.plot(evaluation_accuracy, label='test')
    ax2.plot(training_accuracy, label='train')
    ax2.set_title('Accuracy')
    ax2.legend(loc='lower right')

# %%
import numpy as np
# PLOT CURVES

names = ["vgg"]
c = 0

for n in names:
    evaluation_cost = np.load("/Users/sandhya/Documents/repos/cv-translator/tune/resnet_evaluation_cost.npy")
    print(min(evaluation_cost))
    evaluation_accuracy = np.load("/Users/sandhya/Documents/repos/cv-translator/tune/resnet_evaluation_accuracy.npy")
    print(max(evaluation_accuracy))
    training_cost = np.load("/Users/sandhya/Documents/repos/cv-translator/tune/resnet_training_cost.npy")
    training_accuracy = np.load("/Users/sandhya/Documents/repos/cv-translator/tune/resnet_training_accuracy.npy")
    c+=1

    my_plot = plot_logs(evaluation_cost, evaluation_accuracy, training_cost, training_accuracy)
    plt.show()
# Out:
# 3.420302440752823
# 0.7764350453172205
